# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Data_for_UCI_named.csv')

# %%
data
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# 5     6.999209  9.109247  3.784066  4.267788  4.429669 -1.857139 -0.670397
# 6     6.710166  3.765204  6.929314  8.818562  2.397419 -0.614590 -1.208826
# 7     6.953512  1.379125  5.719400  7.870307  3.224495 -0.748998 -1.186517
# 8     4.689852  4.007747  1.478573  3.733787  4.041300 -1.410344 -1.238204
# 9     9.841496  1.413822  9.769856  7.641616  4.727595 -1.991363 -0.857637
# 10    5.930110  6.730873  6.245138  0.533288  2.327092 -0.702501 -1.116920
# ...

# %%
#Creating File

# %%
sha=data.shape

# %%
data.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
data.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %%
si=data.groupby('stabf').size()

# %%
plt.figure(figsize=(15,10))
data1=pd.DataFrame(data[['tau1','p1','g1','stab','stabf']])
data1.plot(kind='density',subplots=True,sharex=False)
plt.show()

# %%
#BOX PLOTTING: SHOWS THE MEAN VALUE AND OUTLIERS OUTSIDE THE BOX
data1.plot(kind='box',subplots=True,sharex=False,sharey=False)
# Out:
# tau1       AxesSubplot(0.125,0.125;0.168478x0.755)
# p1      AxesSubplot(0.327174,0.125;0.168478x0.755)
# g1      AxesSubplot(0.529348,0.125;0.168478x0.755)
# stab    AxesSubplot(0.731522,0.125;0.168478x0.755)
# dtype: object

# %%
pd.plotting.scatter_matrix(data1)
plt.show()

# %%
#data taking
data=pd.read_csv('Data_for_UCI_named.csv')
print(data.head())
y=data['stabf'].values
print(y)
X=data.drop(['stabf'],axis=1).values
y=np.where(y=='stable',1,-1)
print(y)
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable
# ['unstable' 'stable' 'unstable' ... 'stable' 'unstable' 'unstable']
# [-1  1 -1 ...  1 -1 -1]

# %%
data.groupby('stabf').size()
# Out:
# stabf
# stable      3620
# unstable    6380
# dtype: int64

# %%
#Plotting the graph for having values without scaling
#Sorting the having dataset on the basis of stability and unstability
# First 3620 rows are Stable and 6380 are unstable grid points using above line
data2=data.sort_values(['stab'], axis=0, 
                 ascending=True, inplace=False) 

data2['New_ID'] = range(1, 1+len(data2))
data2.set_index("New_ID", inplace = True)
plt.scatter(data2.iloc[:300,0],data2.iloc[:300,1],color='red',marker='o',label='Stable')
plt.scatter(data2.iloc[-300:,0],data2.iloc[-300:,1],color='blue',marker='*',label='UN Stable')
plt.plot()
plt.show()
#SCATTER PLOT FOR STABLE AND UNSTABLE GRIDS BASED ON FIRST 2 FEATURES

# %%
 
#scaling data to some set fro better training the model    
from sklearn.preprocessing import StandardScaler
 scaler=StandardScaler().fit(X)
 rescaledX=scaler.transform(X)
 rescaledX[0:5,:]
# Out:
# array([[-0.83537431, -0.79131661,  1.14170354,  1.65210289,  0.01739718,
#          1.0794055 , -0.01707819, -1.09254499,  0.45746733,  1.22001311,
#          1.32162751,  1.57902607,  1.07312049],
#        [ 1.47829663, -0.12670487, -0.80311147, -1.41504291,  1.75212436,
#         -1.59361879, -1.43815844, -0.01157525, -0.40679143,  1.23035426,
#          0.13542358,  0.93625569, -0.58748693],
#        [ 1.35709296,  1.31213982, -0.80349871, -1.47150374, -0.45849151,
#          0.09825304, -0.06283962,  0.76096342, -1.3198525 ,  0.88129868,
#          1.14659574, -1.51380226, -0.33209522],
#        [-1.65313833,  0.88228867, -0.27835446, -1.06090088,  0.28425038,
#          0.51390386, -1.59104623,  0.58341424, -0.2873044 ,  1.64725009,
#          1.47454259, -0.59175046,  0.35592213],
#        [-0.77154307,  0.86010818, -0.11166965,  1.68011424, -0.2980753 ,
#          0.28744967, -1.3763432 ,  1.60663583,  0.99222554, -0.25361001,
# ...

# %%
#Scaled values
rescaledX
# Out:
# array([[-0.83537431, -0.79131661,  1.14170354, ...,  1.32162751,
#          1.57902607,  1.07312049],
#        [ 1.47829663, -0.12670487, -0.80311147, ...,  0.13542358,
#          0.93625569, -0.58748693],
#        [ 1.35709296,  1.31213982, -0.80349871, ...,  1.14659574,
#         -1.51380226, -0.33209522],
#        ...,
#        [-1.05234609, -0.87804866,  1.28587062, ..., -1.37001303,
#         -1.38205402, -1.28776846],
#        [ 1.59768553, -0.45784646, -0.90902909, ...,  1.32772953,
#          1.06982944,  0.59749703],
#        [ 0.4669346 ,  0.55855544, -0.32829064, ..., -0.53325125,
#          1.52285961,  0.79996368]])

# %%
#PLOTIING GRAPH FOR SCALED VALUES 
data3=pd.DataFrame(rescaledX)
data3=data3.sort_values([12], axis=0, 
                 ascending=True, inplace=False) 

data3['New_ID'] = range(1, 1+len(data2))
data3.set_index("New_ID", inplace = True)
plt.scatter(data2.iloc[:300,0],data2.iloc[:300,1],color='red',marker='o',label='Stable')
plt.scatter(data2.iloc[-300:,0],data2.iloc[-300:,1],color='blue',marker='*',label='UN Stable')
plt.plot()
plt.show()

# %%
#GRAPH BETWEEN ANY FEATURE WITH STAB FEATURE VALUE IN THE DATA SET WILL BET CLEARLY CLASSIFIED
plt.scatter(data2.iloc[:300,0],data2.iloc[:300,12],color='red',marker='o',label='Stable')
plt.scatter(data2.iloc[-300:,0],data2.iloc[-300:,12],color='blue',marker='*',label='UN Stable')
plt.plot()
plt.show()

# %%
sns.countplot(data['stabf'])

# %%
#Splitting data
#we have methods to split data some of them are 
#1. TRain test split
#2. sampling : we can split data using sampling method from numpy libray rather than sklearn

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(
        rescaledX,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 13)
# (2000, 13)
# (8000,)
# (2000,)

# %%
#Developing the model
#Perceptron model
class Perceptron(object):
        def __init__(self, eta, n_iter):
                self.eta = eta
                self.n_iter = n_iter
        def fit(self, X, y):
                self.w_ = np.zeros(1 + X.shape[1])
                self.errors_=[]
                plot_X=[]
                plot_y=[]
                for _ in range(self.n_iter):
                        errors=0
                        for xi, target in zip(X, y):
                                plot_X.append(xi)
                                plot_y.append(self.predict(xi))
                                error = target - self.predict(xi)
                                if error != 0:
                                        update = self.eta * error
                                        self.w_[1:] += update * xi
                                        self.w_[0] += update
                                        errors+=int(update!=0.0)
                        self.errors_.append(errors)
                return self
        def net_input(self, X):
                return np.dot(X, self.w_[1:]) + self.w_[0]
        def predict(self, X):
                return np.where(self.net_input(X) >= 0.0, 1, -1)

# %%
#fitting the data intothe perceptron model
""""from sklearn.linear_model import Perceptron"""
ppn=Perceptron(n_iter=400, eta=0.4)
print(X_train)
ppn.fit(X_train, y_train)
# Out:
# [[-1.5003169  -0.54386024  1.41423725 ...  1.41805647  0.56750031
#   -0.47262194]
#  [-0.70412076 -1.24442346 -0.18435405 ... -1.50944621  0.45672388
#   -1.03374438]
#  [-1.17302533  1.70984835  0.1776954  ...  0.65367934  0.64456475
#   -0.15363308]
#  ...
#  [-1.17217229  0.42686915  0.82665883 ...  0.16986441 -1.36065413
#   -0.62969207]
#  [-1.6013616   0.16517067 -1.34363445 ...  1.21072922 -0.45341313
#   -1.95426473]
#  [ 1.10618809 -1.26325435  0.59960012 ...  1.27921416 -1.04829421
#    0.38965611]]

# %%
#testing the data
y_pred=ppn.predict(X_test)

# %%
#printing the accuracy of testing and misclassified sample
ms=(y_test!=y_pred).sum()
print('misclassified samples: %d'%(y_test!=y_pred).sum())#compute
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print('Predicting Accuracy:%.2f'%accuracy_score(y_test,y_pred))
# Out:
# misclassified samples: 8
# Predicting Accuracy:1.00

# %%
#pickling the trained model into the file
import pickle
with open("perceptron_trained_model","wb") as f:
    pickle.dump(ppn,f)

# %%
#plotting the graph for errors occured while training 
plt.plot(range(1,len(ppn.errors_)+1),ppn.errors_,marker='o')
plt.xlabel("Number of iterations")
plt.ylabel("ERROR VALUES")
plt.show()

# %%
## Wrting data to file
with open('PerceptronData.txt','w') as fp:
    fp.write("Shape of the DataSET:              ")
    fp.write(str(sha))
    fp.write("\n")
    fp.write("Size of stable and unstable data:  ")
    fp.write(str(si))
    fp.write("\n")
    fp.write("Shape of trained Data:             ")
    fp.write(str(X_train.shape))
    fp.write("\n")
    fp.write("Shape of tested Data:              ")
    fp.write(str(X_test.shape))
    fp.write("\n")
    fp.write("Misclassified samples:             ")
    fp.write(str(ms))
    fp.write("\n")
    fp.write("Testing Data Accuracy:             ")
    fp.write(str(acc))
    fp.write("\n")

# %%
with open('PerceptronData.txt','r') as fp:
    PP=fp.readlines()

# %%
for i in PP:
    print(i.strip())
# Out:
# Shape of the DataSET:              (10000, 14)
# Size of stable and unstable data:  stabf
# stable      3620
# unstable    6380
# dtype: int64
# Shape of trained Data:             (8000, 13)
# Shape of tested Data:              (2000, 13)
# Misclassified samples:             8
# Testing Data Accuracy:             0.996
